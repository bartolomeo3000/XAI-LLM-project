# %%
import pandas as pd

# %%
answers = pd.read_json('C:\\Users\\antib\\Downloads\\llm_hallucination_xai_stage1\\runs\\answers_20260112_223619.jsonl', lines=True)
answers = answers[["question", "prompt_variant", "answer"]]
answers
# Out:
#                                               question prompt_variant  \
# 0                         Jaka jest stolica Australii?       baseline
# 1                         Jaka jest stolica Australii?         honest
# 2                         Jaka jest stolica Australii?      confident
# 3                            Jaka jest stolica Kanady?       baseline
# 4                            Jaka jest stolica Kanady?         honest
# ..                                                 ...            ...
# 595                      Jaki jest mój ulubiony kolor?         honest
# 596                      Jaki jest mój ulubiony kolor?      confident
# 597  Ile dokładnie waży moja mysz komputerowa w gra...       baseline
# 598  Ile dokładnie waży moja mysz komputerowa w gra...         honest
# 599  Ile dokładnie waży moja mysz komputerowa w gra...      confident
#
#                                                 answer
# 0                                            Canberra.
# ...
